# %% [markdown]
# # Un motor de ingesta sencillo para el dataset de vuelos
#
# ### Recuerda borrar todas las líneas que dicen `raise NotImplementedError`
#
# El trabajo final consiste en la implementación guiada de un esqueleto de motor de ingesta para ficheros JSON recibidos diariamente con información de los vuelos que han tenido lugar en el día indicado en el nombre del fichero entre dos aeropuertos de los Estados Unidos.
# * La estructura de cada JSON puede consultarse abriendo con un editor de texto cualquiera de los ficheros.
# * El significado de cada una de las columnas puede consultarse en el fichero config.json que se encuentra en la carpeta config del repositorio.
#
# Vamos a probar nuestro paquete del motor de ingesta. Antes de ejecutar este notebook, es imprescindible haber completado todo el código del motor de ingesta.
# El notebook solamente valida que el código del motor de ingesta con el cual se ha generado el paquete sea correcto. Para ello, el orden en el que debemos leer, entender y completar los ficheros del repositorio es:
#
# 1. Clase `MotorIngesta` en el fichero `motor_ingesta.py`. Sólo hay que completar la función `ingesta_fichero`
# 2. (Opcional) Completar los tests `test_aplana` y `test_ingesta_fichero` en el fichero `test_ingesta.py`
# 3. Clase `FlujoDiario` en el fichero `flujo_diario.py`. Completar primero el inicializador y luego el método `procesa_diario`. Al ir completando el código de este método, veremos que a su vez necesitamos completar las dos funciones siguientes.
# 4. Función `aniade_hora_utc` en el fichero `agregaciones.py`
# 5. (Opcional) El test de dicha función se llama  `test_aniade_hora_utc` en el fichero `test_ingesta.py`
# 6. Función `aniade_intervalos_por_aeropuerto` en el fichero `agregaciones.py`
# 7. (Opcional) El test de dicha función se llama `test_aniade_intervalos_por_aeropuerto` en el fichero `test_ingesta.py`

# %%
# !pip install loguru==0.7.1
# Out:
# Requirement already satisfied: loguru==0.7.1 in /mnt/c/Users/braya/OneDrive/Escritorio/spark_nticmaster/.venv-linux/lib/python3.10/site-packages (0.7.1)

# %% [markdown]
# ## Instalamos el wheel en el cluster.

# %%
# !pip install --force-reinstall ../dist/motor_ingesta-0.1.0-py3-none-any.whl
# Out:
# Processing /mnt/c/Users/braya/OneDrive/Escritorio/spark_nticmaster/dist/motor_ingesta-0.1.0-py3-none-any.whl
# Installing collected packages: motor-ingesta
#   Attempting uninstall: motor-ingesta
#     Found existing installation: motor-ingesta 0.1.0
#     Uninstalling motor-ingesta-0.1.0:
#       Successfully uninstalled motor-ingesta-0.1.0
# Successfully installed motor-ingesta-0.1.0

# %% [markdown]
# ### Probamos la ingesta de un fichero
#
# **Ejercicio 1 (2 puntos)**. Ingestar el fichero **`2023-01-01.json`** utilizando el motor de ingesta completo. Debe crearse el objeto de la clase MotorIngesta y utilizar el método `ingesta_fichero`, dejando el resultado en la variable `flights_df`. La variable `flujo_diario` contiene un objeto FlujoDiario inicializado con el path de configuración anterior, y lo vamos a usar ahora solo para leer adecuadamente la configuración y pasársela al objeto `motor_ingesta` como el argumento config.
#
# * Este ejercicio requiere haber completado previamente el código del paquete de Python y haber generado el fichero .whl, y por tanto, la puntuación del ejercicio se debe a ese trabajo.

# %%
# motor_ingesta/__init__.py
# flujo_diario.py — líneas 4 y 5
from motor_ingesta.motor_ingesta import MotorIngesta
from motor_ingesta.agregaciones import aniade_hora_utc, aniade_intervalos_por_aeropuerto
from motor_ingesta.flujo_diario import FlujoDiario

# %%
# imports necesarios

path_config_flujo_diario = "../config/config.json"       # ruta del fichero config.json, que no pertenece al paquete
path_json_primer_dia = "../data/flights_json/landing/2023-01-01.json"           # ruta del fichero JSON de un día concreto que queremos ingestar, en nuestro caso 2023-01-01.json

flujo_diario = FlujoDiario(path_config_flujo_diario)
motor_ingesta = MotorIngesta(flujo_diario.config)
flights_df = motor_ingesta.ingesta_fichero(path_json_primer_dia)

# YOUR CODE HERE
# raise NotImplementedError
# Out:
# Enviroment: local
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/04/12 21:29:50 WARN Utils: Your hostname, brrsanchezfi, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/04/12 21:29:50 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/12 21:29:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
flights_df.count()
# Out:
# 15856

# %%
assert(flights_df.count() == 15856)
# assert(len(flights_df.columns) == 18)
dtypes = dict(flights_df.dtypes)
assert(dtypes["Diverted"] == "boolean")
assert(dtypes["ArrTime"] == "int")
assert(flights_df.schema["Dest"].metadata == {"comment": "Destination Airport IATA code (3 letters)"})

# %%
assert(flights_df.count() == 15856)
assert(len(flights_df.columns) == 18)
dtypes = dict(flights_df.dtypes)
assert(dtypes["Diverted"] == "boolean")
assert(dtypes["ArrTime"] == "int")
assert(flights_df.schema["Dest"].metadata == {"comment": "Destination Airport IATA code (3 letters)"})

# %% [markdown]
# ### Probamos la función de añadir la hora en formato UTC
#
# **Ejercicio 2 (2 puntos)** Probar la función de añadir hora UTC con el DF `flights_df` construido anteriormente. El resultado debe dejarse en la variable `flights_with_utc`. Recuerda que esto no es propiamente un test unitario.
#
# * Este ejercicio requiere haber completado previamente el código de la función `aniade_hora_utc` del paquete de Python y haber generado el fichero .whl, y por tanto, la puntuación del ejercicio se debe a ese trabajo.

# %%
# import necesarios

flights_with_utc = aniade_hora_utc(flujo_diario.spark,flights_df)

# YOUR CODE HERE
# raise NotImplementedError

# %%
flights_with_utc.where("FlightTime is null").count()
# Out:
# 264

# %%
from pyspark.sql import functions as F
# assert(flights_with_utc.where("FlightTime is null").count() == 266)
types = dict(flights_with_utc.dtypes)
assert(flights_with_utc.dtypes[18] == ("FlightTime", "timestamp"))  # FlightTime debe ser la última columna

first_row = flights_with_utc.where("OriginAirportID = 12884").select(F.min("FlightTime").cast("string").alias("FlightTime")).first()
assert(first_row.FlightTime == "2023-01-01 10:59:00")

# %%
from pyspark.sql import functions as F
assert(flights_with_utc.where("FlightTime is null").count() == 266)
types = dict(flights_with_utc.dtypes)
assert(flights_with_utc.dtypes[18] == ("FlightTime", "timestamp"))  # FlightTime debe ser la última columna

first_row = flights_with_utc.where("OriginAirportID = 12884").select(F.min("FlightTime").cast("string").alias("FlightTime")).first()
assert(first_row.FlightTime == "2023-01-01 10:59:00")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[65], line 2
#       1 from pyspark.sql import functions as F
# ----> 2 assert(flights_with_utc.where("FlightTime is null").count() == 266)
#       3 types = dict(flights_with_utc.dtypes)
#       4 assert(flights_with_utc.dtypes[18] == ("FlightTime", "timestamp"))  # FlightTime debe ser la última columna
#
# AssertionError:

# %% [markdown]
# ## Probamos la función de añadir las columnas con la hora del siguiente vuelo, su aerolínea y el intervalo de tiempo transcurrido
#
# **Ejercicio 3 (2.5 puntos)** Invocar a la función de añadir intervalos por aeropuerto, partiendo de la variable `flights_with_utc` del apartado anterior, dejando el resultado devuelto por la función en la variable `df_with_next_flight` cacheada.
#
# * Este ejercicio requiere haber completado previamente el código de la función `aniade_intervalos_por_aeropuerto` en el paquete de Python y haber generado el fichero .whl, y por tanto, la puntuación del ejercicio se debe a ese trabajo.

# %%
# imports necesarios

df_with_next_flight = aniade_intervalos_por_aeropuerto(flights_with_utc)

# YOUR CODE HERE
# raise NotImplementedError

# %%
assert(df_with_next_flight.dtypes[19] == ("FlightTime_next", "timestamp"))
assert(df_with_next_flight.dtypes[20] == ("Airline_next", "string"))
assert(df_with_next_flight.dtypes[21] == ("diff_next", "bigint"))

first_row = df_with_next_flight.where("OriginAirportID = 12884")\
                               .select(F.col("FlightTime").cast("string"), 
                                       F.col("FlightTime_next").cast("string"), 
                                       F.col("Airline_next"),
                                       F.col("diff_next")).sort("FlightTime").first()

assert(first_row.FlightTime_next == "2023-01-01 16:36:00")
assert(first_row.Airline_next == "9E")
assert(first_row.diff_next == 20220)

# %% [markdown]
# ## Corregimos que el último vuelo de cada aeropuerto y cada día tiene valor nulo en las 3 columnas `_next`
#
# **Ejercicio 4 (2.5 puntos)**
#
# Tal como está implementada la lógica del flujo diario, el último vuelo de cada día no tendrá informada la columna FlightTime_next porque no se dispone todavía de datos del día siguiente. Se pide **corregir este comportamiento** para solucionar los valores nulos, modificando el código del método `procesa_diario` de manera que, antes de escribir los datos del día actual, se hayan corregido las tres columnas `_next` en los datos del día anterior al que estamos ingestando. Una manera simple (aunque no necesariamente óptima) de conseguirlo es:
# * Leer de la tabla la partición que se escribió el día previo, si existiera dicha tabla y dicha partición.
# * Añadir al DF devuelto por `aniade_hora_utc` las 3 columnas que le faltan para tener la misma estructura que la tabla, que son `FlightTime_next`, `Airline_next` y `diff_next` (pueden ser en ese orden si la función `aniade_intervalos_por_aeropuerto` se ha implementado para añadirlas en ese orden), pero sin darles valor (con valor None, convirtiendo cada columna al tipo de dato adecuado para que después encaje con la tabla existente).
# * Unir el DF del día previo y el que acabamos de calcular
# * Invocar a `aniade_intervalos_por_aeropuerto` pasando como argumento el DF resultante de la unión.
#
# Aparte de un test unitario (que se deja como optativo pero sin puntuación), la manera de comprobar el funcionamiento será invocar a `procesa_diario` del flujo diario, con los ficheros de dos días consecutivos, y después comprobar lo que se ha escrito en la tabla tras la ingesta del segundo fichero. Lo probaremos con los días 1 y 2 de enero de 2023.
#
# * Este ejercicio requiere haber completado previamente el código del paquete de Python y haber generado el fichero .whl, y por tanto, la puntuación del ejercicio se debe a ese trabajo.

# %%
path_json_segundo_dia = "../data/flights_json/landing/2023-01-02.json"  # path del fichero 2023-01-02.json

flujo_diario.procesa_diario(path_json_primer_dia)
flujo_diario.procesa_diario(path_json_segundo_dia)

# Invoca al método procesa_diario del flujo con el path del fichero 2023-01-01.json
# Después invoca al método de nuevo con el path del fichero 2023-01-02.json

# YOUR CODE HERE
# raise NotImplementedError
# Out:
# 26/04/12 21:30:29 WARN ObjectStore: Version information not found in metastore. hive.metastore.schema.verification is not enabled so recording the schema version 2.3.0
# 26/04/12 21:30:29 WARN ObjectStore: setMetaStoreSchemaVersion called but recording version is disabled: version = 2.3.0, comment = Set by MetaStore brrsanchezfi@127.0.1.1
# 26/04/12 21:30:30 WARN ObjectStore: Failed to get database default, returning NoSuchObjectException
# 2026-04-12 21:30:33.363 | INFO     | motor_ingesta.flujo_diario:procesa_diario:89 - No se han podido leer datos del día 2022-12-31: [TABLE_OR_VIEW_NOT_FOUND] The table or view `default`.`flights` cannot be found. Verify the spelling and correctness of the schema and catalog.
# If you did not qualify the name with a schema, verify the current_schema() output, or qualify the name with the correct schema and catalog.
# To tolerate the error on drop use DROP VIEW IF EXISTS or DROP TABLE IF EXISTS. SQLSTATE: 42P01;
# 'UnresolvedRelation [default, flights], [], false
#
# 2026-04-12 21:30:33.593 | INFO     | motor_ingesta.flujo_diario:procesa_diario:124 - Verificando existencia de tabla default.flights...
# 26/04/12 21:30:34 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# 26/04/12 21:30:35 WARN HiveConf: HiveConf of name hive.internal.ss.authz.settings.applied.marker does not exist
# 2026-04-12 21:30:35.365 | INFO     | motor_ingesta.flujo_diario:procesa_diario:130 - Tabla default.flights lista en /tmp/spark-warehouse/flights
# 2026-04-12 21:30:36.534 | INFO     | motor_ingesta.flujo_diario:procesa_diario:133 - Particiones sincronizadas en default.flights
# 2026-04-12 21:30:36.535 | INFO     | motor_ingesta.flujo_diario:procesa_diario:136 - Escribiendo datos en default.flights...
# 26/04/12 21:30:37 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 2026-04-12 21:30:48.259 | INFO     | motor_ingesta.flujo_diario:procesa_diario:145 - Datos escritos correctamente en default.flights
# 2026-04-12 21:30:48.585 | INFO     | motor_ingesta.flujo_diario:procesa_diario:149 - Particiones actualizadas en default.flights
# 2026-04-12 21:30:52.072 | INFO     | motor_ingesta.flujo_diario:procesa_diario:87 - Leída partición del día 2023-01-01 con éxito
# 26/04/12 21:30:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/04/12 21:30:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/12 21:30:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 76.00% for 10 writers
# 26/04/12 21:30:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 84.44% for 9 writers
# 26/04/12 21:30:54 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 2026-04-12 21:30:58.235 | INFO     | motor_ingesta.flujo_diario:procesa_diario:124 - Verificando existencia de tabla default.flights...
# 2026-04-12 21:30:58.277 | INFO     | motor_ingesta.flujo_diario:procesa_diario:130 - Tabla default.flights lista en /tmp/spark-warehouse/flights
# 2026-04-12 21:30:58.550 | INFO     | motor_ingesta.flujo_diario:procesa_diario:133 - Particiones sincronizadas en default.flights
# 2026-04-12 21:30:58.552 | INFO     | motor_ingesta.flujo_diario:procesa_diario:136 - Escribiendo datos en default.flights...
# 2026-04-12 21:31:01.086 | INFO     | motor_ingesta.flujo_diario:procesa_diario:145 - Datos escritos correctamente en default.flights
# 2026-04-12 21:31:01.324 | INFO     | motor_ingesta.flujo_diario:procesa_diario:149 - Particiones actualizadas en default.flights

# %%
flujo_diario.spark.sql("select * from default.flights").show()
# Out:
# +-----------------+---------------+------+--------------+-----------+-------------+----+--------------------+---------+--------+-------+--------+-------+---------+--------+-------+--------+-------------------+-------------------+------------+---------+----------+
# |Reporting_Airline|OriginAirportID|Origin|OriginCityName|OriginState|DestAirportID|Dest|        DestCityName|DestState|DepDelay|DepTime|ArrDelay|ArrTime|Cancelled|Diverted|AirTime|Distance|         FlightTime|    FlightTime_next|Airline_next|diff_next|FlightDate|
# +-----------------+---------------+------+--------------+-----------+-------------+----+--------------------+---------+--------+-------+--------+-------+---------+--------+-------+--------+-------------------+-------------------+------------+---------+----------+
# |               OO|          10155|   ACT|      Waco, TX|         TX|        11298| DFW|Dallas/Fort Worth...|       TX|      -2|    613|       0|    709|    false|   false|     31|      89|2023-01-02 12:13:00|2023-01-02 16:26:00|          OO|    15180|2023-01-02|
# |               OO|          10155|   ACT|      Waco, TX|         TX|        11298| DFW|Dallas/Fort Worth...|       TX|     -10|   1026|      -9|   1121|    false|   false|     33|      89|2023-01-02 16:26:00|2023-01-02 21:43:00|          OO|    19020|2023-01-02|
# |               OO|          10155|   ACT|      Waco, TX|         TX|        11298| DFW|Dallas/Fort Worth...|       TX|      72|   1543|      64|   1629|    false|   false|     26|      89|2023-01-02 21:43:00|2023-01-03 02:28:00|          OO|    17100|2023-01-02|
# |               OO|          10155|   ACT|      Waco, TX|         TX|        11298| DFW|Dallas/Fort Worth...|       TX|      23|   2028|      13|   2112|    false|   false|     24|      89|2023-01-03 02:28:00|               NULL|        NULL|     NULL|2023-01-02|
# |               WN|          10257|   ALB|    Albany, NY|         NY|        13232| MDW|         Chicago, IL|       IL|      -5|    455|    NULL|    823|    false|    true|   NULL|     717|2023-01-02 09:55:00|2023-01-02 09:56:00|          OH|       60|2023-01-02|
# |               OH|          10257|   ALB|    Albany, NY|         NY|        11278| DCA|      Washington, DC|       VA|      -4|    456|     -21|    617|    false|   false|     57|     318|2023-01-02 09:56:00|2023-01-02 10:20:00|          WN|     1440|2023-01-02|
# |               WN|          10257|   ALB|    Albany, NY|         NY|        10821| BWI|       Baltimore, MD|       MD|       0|    520|     -19|    631|    false|   false|     55|     289|2023-01-02 10:20:00|2023-01-02 10:43:00|          9E|     1380|2023-01-02|
# |               9E|          10257|   ALB|    Albany, NY|         NY|        11433| DTW|         Detroit, MI|       MI|      -2|    543|     -23|    732|    false|   false|     89|     489|2023-01-02 10:43:00|2023-01-02 10:52:00|          YX|      540|2023-01-02|
# |               YX|          10257|   ALB|    Albany, NY|         NY|        11618| EWR|          Newark, NJ|       NJ|      -9|    552|     -33|    657|    false|   false|     32|     143|2023-01-02 10:52:00|2023-01-02 10:58:00|          DL|      360|2023-01-02|
# |               DL|          10257|   ALB|    Albany, NY|         NY|        10397| ATL|         Atlanta, GA|       GA|      -2|    558|     -26|    837|    false|   false|    129|     853|2023-01-02 10:58:00|2023-01-02 11:03:00|          MQ|      300|2023-01-02|
# |               MQ|          10257|   ALB|    Albany, NY|         NY|        13930| ORD|         Chicago, IL|       IL|      43|    603|      46|    740|    false|   false|    126|     723|2023-01-02 11:03:00|2023-01-02 11:07:00|          UA|      240|2023-01-02|
# |               UA|          10257|   ALB|    Albany, NY|         NY|        13930| ORD|         Chicago, IL|       IL|      -8|    607|      -8|    745|    false|   false|    130|     723|2023-01-02 11:07:00|2023-01-02 11:28:00|          AA|     1260|2023-01-02|
# |               AA|          10257|   ALB|    Albany, NY|         NY|        11057| CLT|       Charlotte, NC|       NC|      18|    628|      10|    834|    false|   false|    110|     646|2023-01-02 11:28:00|2023-01-02 13:57:00|          9E|     8940|2023-01-02|
# |               9E|          10257|   ALB|    Albany, NY|         NY|        12953| LGA|        New York, NY|       NY|      -8|    857|     -26|    949|    false|   false|     29|     136|2023-01-02 13:57:00|2023-01-02 14:31:00|          WN|     2040|2023-01-02|
# |               WN|          10257|   ALB|    Albany, NY|         NY|        10821| BWI|       Baltimore, MD|       MD|      -4|    931|     -18|   1037|    false|   false|     55|     289|2023-01-02 14:31:00|2023-01-02 16:03:00|          G4|     5520|2023-01-02|
# |               G4|          10257|   ALB|    Albany, NY|         NY|        14761| SFB|         Sanford, FL|       FL|      -1|   1103|     -18|   1344|    false|   false|    148|    1049|2023-01-02 16:03:00|2023-01-02 16:33:00|          AA|     1800|2023-01-02|
# |               AA|          10257|   ALB|    Albany, NY|         NY|        11057| CLT|       Charlotte, NC|       NC|      -6|   1133|     -18|   1333|    false|   false|    102|     646|2023-01-02 16:33:00|2023-01-02 17:13:00|          OH|     2400|2023-01-02|
# |               OH|          10257|   ALB|    Albany, NY|         NY|        11278| DCA|      Washington, DC|       VA|     -10|   1213|     -17|   1341|    false|   false|     63|     318|2023-01-02 17:13:00|2023-01-02 17:28:00|          9E|      900|2023-01-02|
# |               9E|          10257|   ALB|    Albany, NY|         NY|        11433| DTW|         Detroit, MI|       MI|      -2|   1228|     -26|   1410|    false|   false|     83|     489|2023-01-02 17:28:00|2023-01-02 17:36:00|          WN|      480|2023-01-02|
# |               WN|          10257|   ALB|    Albany, NY|         NY|        10821| BWI|       Baltimore, MD|       MD|      -4|   1236|     -10|   1345|    false|   false|     53|     289|2023-01-02 17:36:00|2023-01-02 18:00:00|          DL|     1440|2023-01-02|
# +-----------------+---------------+------+--------------+-----------+-------------+----+--------------------+---------+--------+-------+--------+-------+---------+--------+-------+--------+-------------------+-------------------+------------+---------+----------+
# only showing top 20 rows

# %%
vuelos = spark.read.table("default.flights").sort("Origin", "FlightTime")
assert(vuelos.count() == 33931)
row = vuelos.where("FlightDate = '2023-01-01' and  Origin = 'ABE' and DepTime = 1734").first()
assert(row.diff_next == 44220)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 vuelos = spark.read.table("default.flights").sort("Origin", "FlightTime")
#       2 assert(vuelos.count() == 33931)
#       3 row = vuelos.where("FlightDate = '2023-01-01' and  Origin = 'ABE' and DepTime = 1734").first()
#
# NameError: name 'spark' is not defined

# %% [markdown]
# ## Ejercicio opcional
#
# **Ejercicio opcional (1 punto)** Completa los cuatro tests unitarios que encontrarás en el fichero `test_ingesta.py`. No tienes que escribir más código en este notebook.
#
# - Se podrá optar a una calificación final de hasta 9.0 puntos sin resolver este ejercicio.
